# %% [markdown]
# Notebook showing usage of the data detective.

# %%
# To import detective from relative folder
import detective.core as detective
import detective.functions as functions
import pandas as pd
pd.options.plotting.backend = "plotly"

def format_dataframe(df: pd.DataFrame) -> pd.DataFrame:
    """Convert states to numeric where possible and format the last_changed."""
    df["state"] = pd.to_numeric(df["state"], errors="coerce")
    df["last_updated_ts"] = pd.to_datetime(
        df["last_updated_ts"].values, errors="ignore", utc=True, unit='s'
    ).tz_localize(None)
    df = df.dropna()
    return df

# %% [markdown]
# Supply the db_url as described in the [recorder integration docs](https://www.home-assistant.io/integrations/recorder/).

# %%
db_url = r"sqlite:///./home-assistant_v2.db"

# %%
db = detective.HassDatabase(db_url) # To init without fetching entities fetch_entities=False
# Out:
# Successfully connected to database sqlite:///./home-assistant_v2.db
# There are 136 entities with data

# %% [markdown]
# Alternatively, detective can discover your database credentials

# %%
# db = detective.db_from_hass_config()

# %% [markdown]
# Entities are listed on an attribute

# %%
db.entities
# Out:
# ['binary_sensor.hoge_retour_temperatuur',
#  'device_tracker.google_maps_107844393315270166717',
#  'device_tracker.google_maps_112384942883283266385',
#  'device_tracker.guest',
#  'device_tracker.sm_a528b',
#  'input_boolean.anyone_home',
#  'input_boolean.guests_at_home',
#  'input_boolean.martin_asleep',
#  'input_select.belichtingstype',
#  'input_select.vera_s_lamp_scene',
#  'light.bedlamp_anne',
#  'light.bedlamp_martin',
#  'light.bedlamp_thijs',
#  'light.eettafel',
#  'light.eettafel_1',
#  'light.eettafel_2',
#  'light.keuken',
#  'light.kinderhoek',
#  'light.lichtstrip',
#  'light.overloop',
#  'light.staander',
#  'light.studeerkamer_bureau',
#  'light.thijs_plafond_lamp',
#  'light.toilet',
#  'light.vensterbank',
#  'light.vera_kroonluchter',
#  'light.vera_kroonluchter_1',
#  'light.vera_kroonluchter_2',
#  'light.vera_kroonluchter_3',
#  'light.wc_hal',
#  'media_player.beeldstromer',
#  'media_player.chromecasts_group',
#  'media_player.geluidstromer',
#  'media_player.huiskamer',
#  'media_player.woonkamer_media',
#  'persistent_notification.http_login',
#  'person.annerieke',
#  'person.gast',
#  'person.martin',
#  'remote.beeldstromer',
#  'scene.bedlampen_uit',
#  'scene.beneden_uit',
#  'scene.cosy',
#  'scene.effectief_avond',
#  'scene.effectief_overdag',
#  'scene.movies',
#  'scene.s_nachts_lezen',
#  'scene.vera_daytime',
#  'scene.vera_evening',
#  'scene.vera_sleeping',
#  'sensor.annual_gas_consumption',
#  'sensor.bewegingssensor_hal',
#  'sensor.co2_intensity',
#  'sensor.degree_days_this_year',
#  'sensor.energy_consumption_tarif_1',
#  'sensor.energy_consumption_tarif_1_cost',
#  'sensor.energy_consumption_tarif_2',
#  'sensor.energy_consumption_tarif_2_cost',
#  'sensor.energy_production_tarif_1',
#  'sensor.energy_production_tarif_1_compensation',
#  'sensor.energy_production_tarif_2',
#  'sensor.energy_production_tarif_2_compensation',
#  'sensor.envoy_121944126276_current_energy_consumption',
#  'sensor.envoy_121944126276_current_energy_production',
#  'sensor.envoy_121944126276_last_seven_days_energy_production',
#  'sensor.envoy_121944126276_lifetime_energy_production',
#  'sensor.envoy_121944126276_today_s_energy_production',
#  'sensor.firebeetle_uptime_sensor',
#  'sensor.firebeetle_wifi_signal',
#  'sensor.gas_consumption',
#  'sensor.gas_consumption_cost',
#  'sensor.gas_consumption_instantaneous',
#  'sensor.gas_consumption_per_weighted_degree_day',
#  'sensor.gas_prognose',
#  'sensor.grid_fossil_fuel_percentage',
#  'sensor.martin_asleep',
#  'sensor.mi_battery_level_1',
#  'sensor.mi_battery_level_2',
#  'sensor.mi_battery_level_3',
#  'sensor.mi_battery_level_4',
#  'sensor.mi_battery_level_5',
#  'sensor.mi_battery_level_6',
#  'sensor.mi_battery_level_7',
#  'sensor.mi_battery_level_8',
#  'sensor.mi_humidity_1',
#  'sensor.mi_humidity_2',
#  'sensor.mi_humidity_3',
#  'sensor.mi_humidity_4',
#  'sensor.mi_humidity_5',
#  'sensor.mi_humidity_6',
#  'sensor.mi_humidity_7',
#  'sensor.mi_humidity_8',
#  'sensor.mi_temperature_1',
#  'sensor.mi_temperature_2',
#  'sensor.mi_temperature_3',
#  'sensor.mi_temperature_4',
#  'sensor.mi_temperature_5',
#  'sensor.mi_temperature_6',
#  'sensor.mi_temperature_7',
#  'sensor.mi_temperature_8',
#  'sensor.phone_distance',
#  'sensor.power_consumption',
#  'sensor.power_production',
#  'sensor.power_tariff',
#  'sensor.sensor_18726_pm10',
#  'sensor.sensor_18726_pm2_5',
#  'sensor.sm_a528b_battery_level',
#  'sensor.sm_a528b_battery_state',
#  'sensor.sm_a528b_ble_transmitter',
#  'sensor.sm_a528b_charger_type',
#  'sensor.sm_a528b_detected_activity',
#  'sensor.sm_t510_battery_level',
#  'sensor.sm_t510_battery_state',
#  'sensor.sm_t510_charger_type',
#  'sensor.sun_next_dawn',
#  'sensor.sun_next_dusk',
#  'sensor.sun_next_midnight',
#  'sensor.sun_next_noon',
#  'sensor.sun_next_rising',
#  'sensor.sun_next_setting',
#  'sensor.vera_tablet_battery_level',
#  'sensor.vera_tablet_battery_state',
#  'sensor.vera_tablet_charger_type',
#  'sensor.vera_tablet_wifi_bssid',
#  'sensor.waze_travel_time',
#  'sensor.weighted_degree_days_this_year',
#  'sun.sun',
#  'switch.aquarium',
#  'switch.stopcontact_versterker',
#  'switch.test_temperature_restart',
#  'switch.versterker_volume',
#  'weather.buienradar',
#  'weather.huis',
#  'zone.home',
#  'zone.werk_anne',
#  'zone.werk_martin']

# %% [markdown]
# Use `fetch_all_data_of()` to get data for a single entity

# %%
df = db.fetch_all_data_of(('zone.home',))
# Out:
#             WITH combined_states AS (
#                 SELECT states.state, states.last_updated_ts, states_meta.entity_id
#                 FROM states
#                 JOIN states_meta
#                 ON states.metadata_id = states_meta.metadata_id
#             )
#             SELECT *
#             FROM combined_states
#             WHERE
#                 entity_id IN ('zone.home')
#             AND
#                 state NOT IN ('unknown', 'unavailable')
#             ORDER BY last_updated_ts DESC
#         LIMIT 50000
# The returned Pandas dataframe has 79 rows of data.

# %%
df.head()
# Out:
#   state  last_updated_ts  entity_id
# 0     1     1.697119e+09  zone.home
# 1     2     1.697117e+09  zone.home
# 2     1     1.697117e+09  zone.home
# 3     2     1.697116e+09  zone.home
# 4     1     1.697114e+09  zone.home

# %% [markdown]
# Use `fetch_all_sensor_data()` to fetch all your sensor data into a pandas dataframe in memory.
#
# **Note** that by default the number of states returned is limited but this can optionally be over-ridden as shown below.

# %%
df = db.fetch_all_sensor_data(limit=100000)
# Out:
#             SELECT states.state, states.last_updated_ts, states_meta.entity_id
#             FROM states
#             JOIN states_meta
#             ON states.metadata_id = states_meta.metadata_id
#             WHERE
#                 states_meta.entity_id  LIKE '%sensor%'
#             AND
#                 states.state NOT IN ('unknown', 'unavailable')
#             ORDER BY last_updated_ts DESC
#         LIMIT 100000
# The returned Pandas dataframe has 100000 rows of data.

# %% [markdown]
# Take a minute to read about the differences between [wide-form and long-form data](https://altair-viz.github.io/user_guide/data.html#long-form-vs-wide-form-data). The Pandas dataframe we have is in long form.

# %%
df
# Out:
#                   state  last_updated_ts  \
# 0                 70.83     1.697119e+09
# 1                 21.01     1.697119e+09
# 2      14.6830025199995     1.697119e+09
# 3              4175.577     1.697119e+09
# 4              6383.134     1.697119e+09
# ...                 ...              ...
# 99995                -1     1.696922e+09
# 99996          12461874     1.696922e+09
# 99997             44694     1.696922e+09
# 99998               222     1.696922e+09
# 99999               430     1.696922e+09
#
#                                                entity_id
# 0                                   sensor.mi_humidity_4
# 1                                sensor.mi_temperature_4
# 2                 sensor.energy_consumption_tarif_2_cost
# 3                                 sensor.gas_consumption
# 4                       sensor.energy_production_tarif_2
# ...                                                  ...
# 99995  sensor.envoy_121944126276_current_energy_consu...
# 99996  sensor.envoy_121944126276_lifetime_energy_prod...
# 99997  sensor.envoy_121944126276_last_seven_days_ener...
# 99998  sensor.envoy_121944126276_today_s_energy_produ...
# 99999  sensor.envoy_121944126276_current_energy_produ...
#
# [100000 rows x 3 columns]

# %% [markdown]
# It is necessary to format the data before we can plot it, and detective provides a functions to assist

# %%
df = format_dataframe(df)

# %%
df.head()
# Out:
#          state               last_updated_ts  \
# 0    70.830000 2023-10-12 14:02:13.298306816
# 1    21.010000 2023-10-12 14:02:13.293864960
# 2    14.683003 2023-10-12 14:02:08.906647040
# 3  4175.577000 2023-10-12 14:02:08.902273024
# 4  6383.134000 2023-10-12 14:02:08.896011008
#
#                                 entity_id
# 0                    sensor.mi_humidity_4
# 1                 sensor.mi_temperature_4
# 2  sensor.energy_consumption_tarif_2_cost
# 3                  sensor.gas_consumption
# 4        sensor.energy_production_tarif_2

# %% [markdown]
# It is straightforward to create your own features, for example to add a `day_of_week` column

# %%
df['day_of_week'] = df['last_updated_ts'].apply(lambda x : x.dayofweek)
df['is_temperature'] = df['entity_id'].apply(lambda x : 'temperature' in x)
# Out:
# C:\Users\mwkor\AppData\Local\Temp\ipykernel_14984\2192202643.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\mwkor\AppData\Local\Temp\ipykernel_14984\2192202643.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# From here you can begin plotting

# %%
df.sort_values(['entity_id', 'last_updated_ts'], inplace=True)
index = df.entity_id.apply(lambda x: 'humid'in x)#=="sensor.mi_humidity_4"
df[index].plot(x='last_updated_ts', y='state', color='entity_id')
# Out:
# C:\Users\mwkor\AppData\Local\Temp\ipykernel_14984\372781952.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
index = df.entity_id.apply(lambda x: 'temp'in x)#=="sensor.mi_humidity_4"
df[index].rename(columns={'state': 'temperature'}).plot(x='last_updated_ts', y='temperature', color='entity_id')
