# %% [markdown]
# # Toying to figure out to collect data from home assistant via its REST API
#
# it works, but it does not expose its long term statistics

# %%
from requests import get

url = "http://192.168.2.3:8123/api"
url_states = url+ '/states'
headers = {
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiI5ZWFjMGVkZDZiMWM0OTQ5OTJlZDY3Yjg3ZmM0MTJkMyIsImlhdCI6MTY5NjgzODI0NSwiZXhwIjoyMDEyMTk4MjQ1fQ.vut4IzgAYDn46MfszZUkuVbWyhk1lLmCEI59is3FsAc",
    "content-type": "application/json",
}

response = get(url_states, headers=headers)
print(response.text)
# Out:
# [{"entity_id":"person.martin","state":"home","attributes":{"editable":true,"id":"martin","latitude":51.8973349,"longitude":5.0799221,"gps_accuracy":17,"source":"device_tracker.google_maps_107844393315270166717","user_id":"38c59bb2dde64cfd89d471afbabb08f3","device_trackers":["device_tracker.google_maps_107844393315270166717","device_tracker.sm_a528b"],"friendly_name":"Martin"},"last_changed":"2023-10-08T13:01:53.012983+00:00","last_updated":"2023-10-09T10:15:54.198600+00:00","context":{"id":"01HC9YZ92PEN6ERD6DYM32G1TX","parent_id":null,"user_id":null}},{"entity_id":"person.annerieke","state":"home","attributes":{"editable":true,"id":"annerieke","latitude":51.8973718,"longitude":5.0798733,"gps_accuracy":16,"source":"device_tracker.google_maps_112384942883283266385","device_trackers":["device_tracker.google_maps_112384942883283266385"],"friendly_name":"Annerieke"},"last_changed":"2023-10-08T21:10:53.184051+00:00","last_updated":"2023-10-09T06:07:53.878313+00:00","context":{"id":"01HC9GS
# ...

# %%
import json
[_ for _ in json.load(response.content)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\mwkor\Repositories\homeassistant_dataanalysis\grab_data.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/mwkor/Repositories/homeassistant_dataanalysis/grab_data.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import json
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mwkor/Repositories/homeassistant_dataanalysis/grab_data.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> [_ for _ in json.load(response.content)]
#
# File c:\Users\mwkor\miniconda3\envs\homeassisant_dataanalysis\Lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
# ...

# %%
[_['entity_id'] for _ in response.json() if 'ensor.gas' in _['entity_id']]
# Out:
# ['sensor.gas_consumption_instantaneous',
#  'sensor.gas_consumption_cost',
#  'sensor.gas_consumption',
#  'sensor.gas_consumption_per_weighted_degree_day',
#  'sensor.gas_prognose']

# %%
[_ for _ in response.json() if 'ensor.gas_c' in _['entity_id']]
# Out:
# [{'entity_id': 'sensor.gas_consumption_instantaneous',
#   'state': '0.00',
#   'attributes': {'source': 'sensor.gas_consumption',
#    'unit_of_measurement': 'm³/min',
#    'icon': 'mdi:chart-line',
#    'friendly_name': 'Gas consumption (instantaneous)'},
#   'last_changed': '2023-10-09T08:21:09.929781+00:00',
#   'last_updated': '2023-10-09T08:21:09.929781+00:00',
#   'context': {'id': '01HC9RD659HEFW1EBWSKHTN7E9',
#    'parent_id': None,
#    'user_id': None}},
#  {'entity_id': 'sensor.gas_consumption_cost',
#   'state': '3.13528800000009',
#   'attributes': {'state_class': 'total',
#    'last_reset': '2023-09-22T10:47:53.210632+00:00',
#    'unit_of_measurement': 'EUR',
#    'device_class': 'monetary',
#    'friendly_name': 'sensor Cost'},
#   'last_changed': '2023-10-09T08:20:09.875309+00:00',
#   'last_updated': '2023-10-09T08:20:09.875309+00:00',
#   'context': {'id': '01HC9RBBGKSJEH7N9XNEABFR2R',
#    'parent_id': None,
#    'user_id': None}},
# ...

# %% [markdown]
# # history

# %%
history_json = get(url + "/history/period?filter_entity_id=sensor.gas_consumption_instantaneous&no_attributes",  headers=headers).json()
history_json
# Out:
# [[{'entity_id': 'sensor.gas_consumption_instantaneous',
#    'state': '0.00',
#    'attributes': {},
#    'last_changed': '2023-10-08T10:22:41.915923+00:00',
#    'last_updated': '2023-10-08T10:22:41.915923+00:00'},
#   {'entity_id': 'sensor.gas_consumption_instantaneous',
#    'state': '0.01',
#    'attributes': {},
#    'last_changed': '2023-10-08T15:40:22.496883+00:00',
#    'last_updated': '2023-10-08T15:40:22.496883+00:00'},
#   {'entity_id': 'sensor.gas_consumption_instantaneous',
#    'state': '0.00',
#    'attributes': {},
#    'last_changed': '2023-10-08T15:46:23.890087+00:00',
#    'last_updated': '2023-10-08T15:46:23.890087+00:00'},
#   {'entity_id': 'sensor.gas_consumption_instantaneous',
#    'state': '0.01',
#    'attributes': {},
#    'last_changed': '2023-10-08T15:50:26.124324+00:00',
#    'last_updated': '2023-10-08T15:50:26.124324+00:00'},
#   {'entity_id': 'sensor.gas_consumption_instantaneous',
#    'state': '0.00',
#    'attributes': {},
# ...

# %% [markdown]
# # recorder

# %%
recorder_json = get(url + "/recorder/statistics_during_period",  headers=headers)#.json()
recorder_json
# Out:
# <Response [404]>
